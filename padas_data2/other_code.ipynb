# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
data = {
    'name': ['Anton', 'Bob', 'Eva', 'Patrick', 'Ken'],
    'gender': ['male', 'male', 'female', 'male', 'female'],
    'age': [33, 37, 29, 28, 34],
    'salary': [100_000, 75_000, 50_000, 65_000, 90_000],
}

df = pd.DataFrame(data)
df
# Out:
#       name  gender  age  salary
# 0    Anton    male   33  100000
# 1      Bob    male   37   75000
# 2      Eva  female   29   50000
# 3  Patrick    male   28   65000
# 4      Ken  female   34   90000

# %%
df['gender'].value_counts(normalize=True)
# Out:
# gender
# male      0.6
# female    0.4
# Name: proportion, dtype: float64

# %%
print(df)
# Out:
#       name  gender  age  salary
# 0    Anton    male   33  100000
# 1      Bob    male   37   75000
# 2      Eva  female   29   50000
# 3  Patrick    male   28   65000
# 4      Ken  female   34   90000

# %%
def g(x):
    return x.mean()
df[['age', 'salary']].apply(g, axis=1)
# Out:
# 0    50016.5
# 1    37518.5
# 2    25014.5
# 3    32514.0
# 4    45017.0
# dtype: float64

# %%
df.map(g)
# Out:
#              name        gender  age  salary
# 0      AntonAnton      malemale   66  200000
# 1          BobBob      malemale   74  150000
# 2          EvaEva  femalefemale   58  100000
# 3  PatrickPatrick      malemale   56  130000
# 4          KenKen  femalefemale   68  180000
